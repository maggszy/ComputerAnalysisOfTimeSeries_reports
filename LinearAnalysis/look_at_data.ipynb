# %%
import matplotlib.pyplot as plt
import scipy.stats as ss
import numpy as np
import pandas as pd
import seaborn as sns
plt.style.use('seaborn')

colors = {'red' : "#B03A2E", 'gray' : "#424949"}
# Out:
# /tmp/ipykernel_89/1584025159.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
df_full = pd.read_csv('openpowerlifting.csv', sep=',')
df_female = df_full[df_full['Sex'] == 'F']
# df_succesful_best = df_female[df_female['Best3DeadliftKg'] > 0][df_female['Best3SquatKg'] > 0][df_female['Best3BenchKg'] > 0]
df_succesful_best = df_female[df_female['Deadlift3Kg'] > 0][df_female['Deadlift2Kg'] > 0]
df = df_succesful_best
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 df_full = pd.read_csv('openpowerlifting.csv', sep=',')
#       2 df_female = df_full[df_full['Sex'] == 'F']
#       3 # df_succesful_best = df_female[df_female['Best3DeadliftKg'] > 0][df_female['Best3SquatKg'] > 0][df_female['Best3BenchKg'] > 0]
#
# ...

# %%
df["Date"]
# Out:
# 0          2018-10-27
# 1          2018-10-27
# 4          2018-10-27
# 5          2018-10-27
# 6          2018-10-27
#               ...
# 1423242    2017-04-01
# 1423244    2017-04-01
# 1423245    2017-04-01
# 1423247    2017-04-01
# 1423248    2017-04-01
# Name: Date, Length: 59031, dtype: object

# %%
df.head()
# Out:
#             Name Sex Event Equipment   Age AgeClass Division  BodyweightKg  \
# 0   Abbie Murphy   F   SBD     Wraps  29.0    24-34     F-OR          59.8
# 1    Abbie Tuong   F   SBD     Wraps  29.0    24-34     F-OR          58.5
# 4   Andrea Rowan   F   SBD     Wraps  45.0    45-49     F-OR         104.0
# 5  April Alvarez   F   SBD     Wraps  37.0    35-39     F-OR          74.0
# 6     Ash Morgan   F   SBD     Wraps  23.0    20-23     F-OR          59.8
#
#   WeightClassKg  Squat1Kg  ...  McCulloch  Glossbrenner  IPFPoints  Tested  \
# 0            60      80.0  ...     324.16        286.42     511.15     NaN
# 1            60     100.0  ...     378.07        334.16     595.65     NaN
# 4           110     120.0  ...     338.91        274.56     550.08     NaN
# 5            75     127.5  ...     354.74        312.20     596.18     NaN
# 6            60     115.0  ...     385.63        340.74     612.23     NaN
#
# ...

# %%
# Out:
#                        Name Sex Event   Equipment   Age AgeClass   Division  \
# 75780        Gisele Mathiau   F   SBD  Single-ply  33.5    24-34       Open
# 75781           Malou Thill   F   SBD  Single-ply  32.5    24-34       Open
# 75783         Karen Cameron   F   SBD  Single-ply  26.5    24-34       Open
# 75784         Edith Scherpf   F   SBD  Single-ply  32.5    24-34       Open
# 75788    Sherry Renee Burns   F   SBD  Single-ply  27.5    24-34       Open
# ...                     ...  ..   ...         ...   ...      ...        ...
# 1060231          Gail Moore   F   SBD  Single-ply  59.0    55-59  Masters 2
# 1060233       Mariet Spronk   F   SBD  Single-ply  51.5    50-54  Masters 2
# 1060237          Jane Smith   F   SBD  Single-ply  50.5    50-54  Masters 2
# 1060238       Susanne Diter   F   SBD  Single-ply  54.5    50-54  Masters 2
# 1060240        Sue Hollands   F   SBD  Single-ply  55.5    55-59  Masters 2
#
# ...

# %%
df.describe()
# Out:
#                 Age  BodyweightKg      Squat1Kg      Squat2Kg      Squat3Kg  \
# count  50283.000000   58955.00000  54275.000000  54115.000000  53648.000000
# mean      30.198357      68.40340     78.019917     70.137348     34.902255
# std       12.087368      16.62405     75.978135     92.684506    116.507483
# min        0.500000      20.87000   -285.000000   -305.000000   -400.000000
# 25%       21.000000      56.60000     70.000000     68.000000    -97.500000
# 50%       27.000000      65.60000     95.000000     97.500000     90.000000
# 75%       37.500000      75.80000    117.500000    122.500000    120.000000
# max       91.500000     184.20000    350.000000    357.500000    365.000000
#
#          Squat4Kg  Best3SquatKg      Bench1Kg      Bench2Kg      Bench3Kg  \
# count  519.000000  53712.000000  55828.000000  55721.000000  55201.000000
# mean    33.826647    113.738407     49.549857     37.768400     -3.103614
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59031 entries, 0 to 1423248
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             59031 non-null  object
#  1   Sex              59031 non-null  object
#  2   Event            59031 non-null  object
#  3   Equipment        59031 non-null  object
#  4   Age              50283 non-null  float64
#  5   AgeClass         50581 non-null  object
#  6   Division         58675 non-null  object
#  7   BodyweightKg     58955 non-null  float64
#  8   WeightClassKg    58654 non-null  object
#  9   Squat1Kg         54275 non-null  float64
#  10  Squat2Kg         54115 non-null  float64
#  11  Squat3Kg         53648 non-null  float64
#  12  Squat4Kg         519 non-null    float64
#  13  Best3SquatKg     53712 non-null  float64
#  14  Bench1Kg         55828 non-null  float64
#  15  Bench2Kg         55721 non-null  float64
# ...

# %% [markdown]
# ## Rzut okiem na rozkłady jednowymiarowe

# %%
def print_metrics(column):
    print("Średnia: ", np.mean(column))
    print("Mediana: ", np.median(column))
    print("Pierwszy kwartyl: ", np.quantile(column, .25))
    print("Trzeci kwartyl: ", np.quantile(column, .75))
    print("Rozstęp międzykwartylowy: ", np.quantile(column, .75) - np.quantile(column, .25))
    print("Rozstęp: ", np.max(column) - np.min(column))
    print("Wariancja: ", np.var(column))
    print("Odchylenie standardowe: ", np.std(column))
    print("Odchylenie przeciętne od średniej: ", np.mean(np.abs(column - np.mean(column))))
    print("Współczynnik zmienności: ", np.std(column)/np.mean(column))

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)}, figsize=(15, 7))
sns.boxplot(data= df, x='Best3SquatKg', ax=ax_box, color=colors['red'])
sns.histplot(data=df, x='Best3SquatKg',bins=35 , ax=ax_hist, color=colors['red'])
ax_box.set(xlabel='')
plt.suptitle(f'Przysiad', fontsize=20);

# %%
print_metrics(df['Best3SquatKg'])
# Out:
# Średnia:  113.73840724605303
# Mediana:  nan
# Pierwszy kwartyl:  nan
# Trzeci kwartyl:  nan
# Rozstęp międzykwartylowy:  nan
# Rozstęp:  470.0
# Wariancja:  1287.741454956805
# Odchylenie standardowe:  35.8851146710834
# Odchylenie przeciętne od średniej:  27.287204583507698
# Współczynnik zmienności:  0.31550569011795876

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)}, figsize=(15, 7))
sns.boxplot(data= df, x='Best3BenchKg', ax=ax_box, color=colors['red'])
sns.histplot(data=df, x='Best3BenchKg',bins=35 , ax=ax_hist, color=colors['red'])
ax_box.set(xlabel='')
plt.suptitle(f'Ławka', fontsize=20);

# %%
print_metrics(df['Best3BenchKg'])
# Out:
# Średnia:  64.41510454438851
# Mediana:  nan
# Pierwszy kwartyl:  nan
# Trzeci kwartyl:  nan
# Rozstęp międzykwartylowy:  nan
# Rozstęp:  317.0
# Wariancja:  466.99283463710134
# Odchylenie standardowe:  21.610016997612504
# Odchylenie przeciętne od średniej:  15.86064949604023
# Współczynnik zmienności:  0.3354805856555122

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)}, figsize=(15, 7))
sns.boxplot(data= df, x='Best3DeadliftKg', ax=ax_box, color=colors['red'])
sns.histplot(data=df, x='Best3DeadliftKg',bins=35 , ax=ax_hist, color=colors['red'])
ax_box.set(xlabel='')
plt.suptitle(f'Martwy', fontsize=20);

# %%
print_metrics(df['Best3DeadliftKg'])
# Out:
# Średnia:  134.45532025545901
# Mediana:  132.5
# Pierwszy kwartyl:  115.0
# Trzeci kwartyl:  152.5
# Rozstęp międzykwartylowy:  37.5
# Rozstęp:  281.9
# Wariancja:  937.2573017384184
# Odchylenie standardowe:  30.614658282241507
# Odchylenie przeciętne od średniej:  23.963298518658114
# Współczynnik zmienności:  0.227693915153934

# %% [markdown]
# ## Regresja dla różnych kombinacji

# %%
def print_reg_metrics(x, y, alpha):
    n = len(x)
    S = np.var(y)
    mx = np.mean(x)
    my = np.mean(y)
    SMD = np.sum((x-mx)**2)
    b0, b1 = np.polyfit(x, y, 1)
    cb0 = ss.t.ppf(q=1-alpha, df=n-2)*S*np.sqrt(1/n + (mx**2)/SMD)
    cb1 = ss.t.ppf(q=1-alpha, df=n-2)*S/np.sqrt(SMD)
    y_roof = x*b1+b0
    SST = np.sum((y - my)**2)
    SSR = np.sum((y_roof - my)**2)
    SSE = np.sum((y_roof - y)**2)

    print("Beta_0: ", b0)
    print("Beta_1: ", b1)
    print(f"C_Beta_0: [ {b0 - cb0} , {b0 + cb0} ]")
    print(f"C_Beta_1: [ {b1 - cb1} , {b1 + cb1} ]")
    print("SST: ", SST)
    print("SSR: ", SSR)
    print("SSE: ", SSE)
    print("R2: ", SSR/SST)                               # czemu to nie jest z (0,1)? XD
    print("Korelacja Pearsona: ", np.corrcoef(x, y)[0][1])

# %%
print_reg_metrics(df["Best3DeadliftKg"], df["Best3BenchKg"], 0.05)
# Out:
# Beta_0:  nan
# Beta_1:  nan
# C_Beta_0: [ nan , nan ]
# C_Beta_1: [ nan , nan ]
# SST:  25885879.816769164
# SSR:  0.0
# SSE:  0.0
# R2:  0.0
# Korelacja Pearsona:  nan

# %%
fig, ax = plt.subplots(1, figsize=(15, 7))
sns.regplot(data=df, x='Best3SquatKg', y='Best3BenchKg',
            scatter_kws={"color": colors['gray']}, line_kws={"color": colors['red']})
plt.suptitle(f'Przysiad - Ławka', fontsize=20);

# %%
fig, ax = plt.subplots(1, figsize=(15, 7))
sns.regplot(data=df, x='Best3SquatKg', y='Best3DeadliftKg', 
            scatter_kws={"color": colors['gray']}, line_kws={"color": colors['red']})
plt.suptitle(f'Przysiad - Martwy', fontsize=20);

# %%
fig, ax = plt.subplots(1, figsize=(15, 7))
sns.regplot(data=df, x='Deadlift2Kg', y='Deadlift3Kg', 
            scatter_kws={"color": colors['gray']}, line_kws={"color": colors['red']})
plt.suptitle(f'Martwy2 - Martwy3', fontsize=20);
#XD

# %%
fig, ax = plt.subplots(1, figsize=(15, 7))
sns.regplot(data=df, x='Best3BenchKg', y='Best3DeadliftKg',
            scatter_kws={"color": colors['gray']}, line_kws={"color": colors['red']})
plt.suptitle(f'Ławka - Martwy', fontsize=20);

# %% [markdown]
# ## Test Jarque Bera

# %%
def test_jarque_bera(data):
    mean = np.mean(data)
    std = np.std(data)

    norm_data = (data - mean)/std

    return ss.jarque_bera(norm_data)

# %%
przysiad_test = test_jarque_bera(df["Best3SquatKg"])
martwy_test = test_jarque_bera(df["Best3DeadliftKg"])

# %%
przysiad_test, martwy_test # nie są z rozkładu normalnego
# Out:
# (Jarque_beraResult(statistic=56741.8261282914, pvalue=0.0),
#  Jarque_beraResult(statistic=10957.35480935903, pvalue=0.0))

# %%
def reg(x, y, alpha):
    n = len(x)
    S = np.var(y)
    mx = np.mean(x)
    my = np.mean(y)
    SMD = np.sum((x-mx)**2)
    b0, b1 = np.polyfit(x, y, 1)
    y_roof = x*b1+b0

    return y_roof

# %%
# x = np.array(df["Best3SquatKg"])
# y = np.array(df["Best3DeadliftKg"])

# y_roof = reg(x,y,0.05)
# e = y - y_roof

# e_test = ss.jarque_bera(e)
# e_test # nie jest z rozkładu normalnego
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: On entry to DLASCL parameter number 4 had an illegal value
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In [20], line 4
#       1 x = np.array(df["Best3SquatKg"])
#       2 y = np.array(df["Best3DeadliftKg"])
# ----> 4 y_roof = reg(x,y,0.05)
#       5 e = y - y_roof
#
# Cell In [19], line 7, in reg(x, y, alpha)
#       5 my = np.mean(y)
#       6 SMD = np.sum((x-mx)**2)
# ----> 7 b0, b1 = np.polyfit(x, y, 1)
#       8 y_roof = x*b1+b0
#      10 return y_roof
#
# File <__array_function__ internals>:180, in polyfit(*args, **kwargs)
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/numpy/lib/polynomial.py:668, in polyfit(x, y, deg, rcond, full, w, cov)
# ...

# %%
def standarization(data):
    mean = np.mean(data)
    std = np.std(data)

    norm_data = (data - mean)/std

    return norm_data

# %%
np.std(e)
# Out:
# 1553.0479792636654

# %%
mu= 0
sigma = 1
norm_e = standarization(e)
xx = np.linspace(min(norm_e),max(norm_e), 10000)
plt.plot(xx, ss.norm.cdf(xx,mu,sigma), label='teoretyczna')
sns.ecdfplot(norm_e, label='empiryczna')
plt.legend()
plt.title(f"$\mu$ = {np.round(np.mean(norm_e),4)}, $\sigma$ = {np.std(norm_e)}")
# Out:
# Text(0.5, 1.0, '$\\mu$ = 0.0, $\\sigma$ = 1.0')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=47b01b49-78b6-4c04-a5a6-f968081bf432' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
